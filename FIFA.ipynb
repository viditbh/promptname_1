# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plb

# %%
df= pd.read_csv(r"C:\Users\Hp\Downloads\fifa_eda_stats (1).csv")
df
# Out:
#          ID               Name  Age  Nationality  Overall  Potential  \
# 0    158023           L. Messi   31    Argentina       94         94
# 1     20801  Cristiano Ronaldo   33     Portugal       94         94
# 2    190871          Neymar Jr   26       Brazil       92         93
# 3    193080             De Gea   27        Spain       91         93
# 4    192985       K. De Bruyne   27      Belgium       91         92
# ..      ...                ...  ...          ...      ...        ...
# 299  183376           L. Fejsa   29       Serbia       82         82
# 300  183280            A. Rami   32       France       82         82
# 301  181786         V. Ćorluka   32      Croatia       82         82
# 302  181291       G. Wijnaldum   27  Netherlands       82         82
# 303  179847           F. Fazio   31    Argentina       82         82
#
#                        Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.head(5)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  €110.5M  €565K           Left  ...         96
# 1             Juventus     €77M  €405K          Right  ...         95
# 2  Paris Saint-Germain  €118.5M  €290K          Right  ...         94
# 3    Manchester United     €72M  €260K          Right  ...         68
# 4      Manchester City    €102M  €355K          Right  ...         88
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# ...

# %%
df.isnull()
# Out:
#         ID   Name    Age  Nationality  Overall  Potential   Club  Value  \
# 0    False  False  False        False    False      False  False  False
# 1    False  False  False        False    False      False  False  False
# 2    False  False  False        False    False      False  False  False
# 3    False  False  False        False    False      False  False  False
# 4    False  False  False        False    False      False  False  False
# ..     ...    ...    ...          ...      ...        ...    ...    ...
# 299  False  False  False        False    False      False  False  False
# 300  False  False  False        False    False      False  False  False
# 301  False  False  False        False    False      False  False  False
# 302  False  False  False        False    False      False  False  False
# 303  False  False  False        False    False      False  False  False
#
#       Wage  Preferred Foot  ...  Composure  Marking  StandingTackle  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                         0
# Wage                          0
# Preferred Foot                0
# International Reputation      0
# Weak Foot                     0
# Skill Moves                   0
# Work Rate                     0
# Body Type                     0
# Position                      0
# Jersey Number                 0
# Joined                        5
# Loaned From                 299
# Contract Valid Until          0
# Height                        0
# Weight                        0
# Crossing                      0
# Finishing                     0
# HeadingAccuracy               0
# ShortPassing                  0
# Volleys                       0
# Dribbling                     0
# Curve                         0
# ...

# %%
df.drop("Loaned From", axis="columns")
# Out:
#          ID               Name  Age  Nationality  Overall  Potential  \
# 0    158023           L. Messi   31    Argentina       94         94
# 1     20801  Cristiano Ronaldo   33     Portugal       94         94
# 2    190871          Neymar Jr   26       Brazil       92         93
# 3    193080             De Gea   27        Spain       91         93
# 4    192985       K. De Bruyne   27      Belgium       91         92
# ..      ...                ...  ...          ...      ...        ...
# 299  183376           L. Fejsa   29       Serbia       82         82
# 300  183280            A. Rami   32       France       82         82
# 301  181786         V. Ćorluka   32      Croatia       82         82
# 302  181291       G. Wijnaldum   27  Netherlands       82         82
# 303  179847           F. Fazio   31    Argentina       82         82
#
#                        Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.drop("Release Clause", axis="columns")
df.drop("Joined", axis="columns")
# Out:
#          ID               Name  Age  Nationality  Overall  Potential  \
# 0    158023           L. Messi   31    Argentina       94         94
# 1     20801  Cristiano Ronaldo   33     Portugal       94         94
# 2    190871          Neymar Jr   26       Brazil       92         93
# 3    193080             De Gea   27        Spain       91         93
# 4    192985       K. De Bruyne   27      Belgium       91         92
# ..      ...                ...  ...          ...      ...        ...
# 299  183376           L. Fejsa   29       Serbia       82         82
# 300  183280            A. Rami   32       France       82         82
# 301  181786         V. Ćorluka   32      Croatia       82         82
# 302  181291       G. Wijnaldum   27  Netherlands       82         82
# 303  179847           F. Fazio   31    Argentina       82         82
#
#                        Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                         0
# Wage                          0
# Preferred Foot                0
# International Reputation      0
# Weak Foot                     0
# Skill Moves                   0
# Work Rate                     0
# Body Type                     0
# Position                      0
# Jersey Number                 0
# Joined                        5
# Loaned From                 299
# Contract Valid Until          0
# Height                        0
# Weight                        0
# Crossing                      0
# Finishing                     0
# HeadingAccuracy               0
# ShortPassing                  0
# Volleys                       0
# Dribbling                     0
# Curve                         0
# ...

# %%
p=df[df['Age']>21]
p
# Out:
#          ID               Name  Age  Nationality  Overall  Potential  \
# 0    158023           L. Messi   31    Argentina       94         94
# 1     20801  Cristiano Ronaldo   33     Portugal       94         94
# 2    190871          Neymar Jr   26       Brazil       92         93
# 3    193080             De Gea   27        Spain       91         93
# 4    192985       K. De Bruyne   27      Belgium       91         92
# ..      ...                ...  ...          ...      ...        ...
# 299  183376           L. Fejsa   29       Serbia       82         82
# 300  183280            A. Rami   32       France       82         82
# 301  181786         V. Ćorluka   32      Croatia       82         82
# 302  181291       G. Wijnaldum   27  Netherlands       82         82
# 303  179847           F. Fazio   31    Argentina       82         82
#
#                        Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
plb.figure(figsize=(10,5))
plb.hist(p['Age'],bins=10,edgecolor="black")
plb.title("Football Players older than 21 years of age")
plb.xlabel("Age")
plb.ylabel("Number of Players")
plb.show()

# %%
cc=df['Nationality'].value_counts()
cc
# Out:
# Nationality
# Spain                   46
# Brazil                  45
# France                  29
# Germany                 28
# Italy                   21
# Belgium                 14
# Argentina               13
# Portugal                13
# England                 11
# Netherlands             10
# Croatia                  8
# Uruguay                  6
# Colombia                 4
# Senegal                  4
# Serbia                   4
# Bosnia Herzegovina       3
# Slovenia                 3
# Poland                   3
# Denmark                  3
# Austria                  2
# Slovakia                 2
# Wales                    2
# Chile                    2
# Greece                   2
# Morocco                  2
# Algeria                  2
# Switzerland              2
# Sweden                   2
# Egypt                    1
# Costa Rica               1
# Gabon                    1
# Korea Republic           1
# Guinea                   1
# Finland                  1
# ...

# %%
countries=["Brazil","Germany","England"]
rc=cc[countries]
data=rc.to_dict()
others=[]
for i in cc:
    if i not in countries:
        others.append(i)
others1=sum(others)
others1
# Out:
# 304

# %%
countries=["Brazil","Germany","England"]
rc=cc[countries]
pidata=rc.to_dict()
others=[]
for i in cc:
    if i not in countries:
        others.append(i)
others1=sum(others)
others1
pidata["others"]= others
#pidata=countries.append(pd.Series({'other':others}))
label=countries+['others']

# %%
cc=df['Nationality'].value_counts()
countries=['Germany', 'Argentina', 'England']
rc=cc[countries]
oc=cc[~cc.index.isin(countries)].sum()
pidata=rc.to_dict()
pidata['other']=oc
plb.figure(figsize=(10,5))
plb.pie(pidata.values(), labels=pidata.keys())
plb.title("Players and their Nationalities")
plb.show()
